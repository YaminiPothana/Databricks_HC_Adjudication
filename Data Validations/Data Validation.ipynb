# %%
# %sql
Select count(*) from healthcare_adjudication.healthcare_adjudication_bronze.patients

# %%
# %sql
Select count(*) from healthcare_adjudication.healthcare_adjudication_bronze.payers
--Select count(*) from healthcare_adjudication.healthcare_adjudication_silver.payers

# %%
# %sql
select count(*) from healthcare_adjudication.healthcare_adjudication_bronze.claims

# %%
# %sql
select * from healthcare_adjudication.healthcare_adjudication_bronze.claims
where claim_id = 9999

# %%
# %sql
select * from healthcare_adjudication.healthcare_adjudication_silver.claims
where claim_id = 9999

# %%
# %sql
select distinct status from healthcare_adjudication.healthcare_adjudication_gold.claim_approval_rate
